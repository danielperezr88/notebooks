# %% [markdown]
# # Tutorial Brief

# %% [markdown]
# In this tutorial we will cover the basics of using Google Custom Search to search the Interner.
#
# Links:
#
# - https://www.google.com/cse/all
# - https://console.developers.google.com/
# - https://developers.google.com/custom-search/json-api/v1/reference/cse/list
#
# Video Tutorial:
#
# http://youtu.be/ewPJs4N8d8M

# %%
from bs4 import BeautifulSoup
#import re
#import sys
#import random
#from time import sleep

# %%
import json
import requests
import pandas as pd

# %% [markdown]
# # Understanding Google Custom Search

# %% [markdown]
# Google Custom Search replaces the depreciated Google Search API. It is designed to search one or more website and to embedded with in the website.
#
# There is still an options to search the complete web. This options combined with no specified website to search retuen results which are very close to what you get when you search Google. The difference in results is due to personalized and localized search results that Google search returns.

# %%
key = "AIzaSyCQJXgPMcslYQnx00c4D3U4zAheyGg8WZk"
cx = "009780631741676379950:7tjrahkzi3i"

# %% [markdown]
# <table class="matchpre">
#     <thead>
#       <tr>
#         <th>Parameter name</th>
#         <th>Value</th>
#         <th>Description</th>
#       </tr>
#     </thead>
#     <tbody>
#     <tr id="required-parameters" class="alt">
#       <td colspan="3"><b>Required parameters</b></td>
#     </tr>
#       <tr id="q">
#         <td><code>q</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           The search expression.
#
#
#         </td>
#       </tr>
#
#     <tr id="optional-parameters" class="alt">
#       <td colspan="3"><b>Optional parameters</b></td>
#     </tr>
#       <tr id="c2coff">
#         <td><code>c2coff</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>Enables or disables&nbsp;</span><a href="https://developers.google.com/custom-search/docs/xml_results#chineseSearch">Simplified and Traditional Chinese Search</a>.&nbsp;<ul><li>The default value for this parameter is&nbsp;<code>0</code>&nbsp;(zero), meaning that the feature is enabled. Supported values are:<ul><li><code>1</code>: Disabled</li><li><code>0</code>: Enabled (default)</li></ul></li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="cr">
#         <td><code>cr</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>R</span><span>estricts search results to documents originating in a particular country. <br></span><ul><li><span>You may use&nbsp;</span><a href="https://developers.google.com/custom-search/docs/xml_results#booleanOperators">Boolean operators</a><span>&nbsp;</span><span>in the</span><span>&nbsp;</span><code>cr</code><span>&nbsp;</span><span>parameter's value.</span><br></li><li>Google Search determines the country of a document by analyzing:<ul><li>the top-level domain (TLD) of the document's URL</li><li>the geographic location of the Web server's IP address</li></ul></li><li>See the&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#countryCollections">Country Parameter Values</a>&nbsp;page for a list of valid values for this parameter.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="cref">
#         <td><code>cref</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>The URL of a&nbsp;</span><a href="http://www.google.com/cse/docs/cref.html">linked</a><span><font color="#222222">&nbsp;custom search engine specification to use for this request.&nbsp;<br><ul><li><span>Does not apply for Google Site Search</span></li><li><font color="#222222" face="Arial"><span>If both&nbsp;</span></font><code>cx</code><span>&nbsp;and&nbsp;</span><code>cref</code><span>&nbsp;are specified, the&nbsp;</span><code>cx</code><span>&nbsp;value is used</span><br></li></ul></font></span>
#
#
#         </td>
#       </tr>
#       <tr id="cx">
#         <td><code>cx</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           The custom search engine ID to use for this request.<br><ul><li>If both&nbsp;<code>cx</code>&nbsp;and&nbsp;<code>cref</code>&nbsp;are specified, the&nbsp;<code>cx</code>&nbsp;value is used.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="dateRestrict">
#         <td><code>dateRestrict</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>Restricts results to URLs based on date. Supported values include:</span><ul><li><code>d[number]</code>: requests results from the specified number of past days.</li><li><code>w[number]</code>: requests results from the specified number of past weeks.</li><li><code>m[number]</code>: requests results from the specified number of past months.</li><li><code>y[number]</code>: requests results from the specified number of past years.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="exactTerms">
#         <td><code>exactTerms</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Identifies a phrase that all documents in the search results must contain.
#
#
#         </td>
#       </tr>
#       <tr id="excludeTerms">
#         <td><code>excludeTerms</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Identifies a word or phrase that should not appear in any documents in the search results.
#
#
#         </td>
#       </tr>
#       <tr id="fileType">
#         <td><code>fileType</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Restricts results to files of a specified extension. A list of file types indexable by Google<span>&nbsp;can be found in Webmaster Tools <a href="https://support.google.com/webmasters/answer/35287?hl=en">Help Center</a>.</span><span><br></span>
#
#
#         </td>
#       </tr>
#       <tr id="filter">
#         <td><code>filter</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Controls turning on or off the duplicate content filter.<ul><li>See&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#automaticFiltering">Automatic Filtering</a>&nbsp;for more information about Google's search results filters. Note that host crowding filtering applies only to multi-site searches.</li><li>By default, Google applies filtering to all search results to improve the quality of those results.</li></ul>
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>0</code>": Turns off duplicate content filter.
#             </li>
#             <li>"<code>1</code>": Turns on duplicate content filter.
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="gl">
#         <td><code>gl</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Geolocation of end user.&nbsp;<ul><li>The&nbsp;<code>gl</code>&nbsp;parameter value is a two-letter country code. The&nbsp;<code>gl</code>&nbsp;parameter boosts search results whose country of origin matches the parameter value. See the&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#countryCodes">Country Codes</a>&nbsp;page for a list of valid values.</li><li>Specifying a&nbsp;<code>gl</code>&nbsp;parameter value should lead to more relevant results. This is particularly true for international customers and, even more specifically, for customers in English- speaking countries other than the United States.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="googlehost">
#         <td><code>googlehost</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           The local Google domain&nbsp;<span>(for example, google.com, google.de, or google.fr) </span>to use to perform the search.&nbsp;
#
#
#         </td>
#       </tr>
#       <tr id="highRange">
#         <td><code>highRange</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <ul><li><span>Specifies the ending value for a search range.</span><br></li><li>Use&nbsp;<code>lowRange</code>&nbsp;and&nbsp;<code>highRange</code>&nbsp;to append an inclusive search range of&nbsp;<code>lowRange...highRange&nbsp;</code>&nbsp;to the query.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="hl">
#         <td><code>hl</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Sets the user interface language.&nbsp;<ul><li>Explicitly setting this parameter improves the performance and the quality of your search results.</li><li>See the&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#wsInterfaceLanguages">Interface Languages</a>&nbsp;section of&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#wsInternationalizing">Internationalizing Queries and Results Presentation</a>&nbsp;for more information, and&nbsp;<a href="https://developers.google.com/custom-search/docs/xml_results#interfaceLanguages">Supported Interface Languages</a>&nbsp;for a list of supported languages.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="hq">
#         <td><code>hq</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>Appends the specified query terms to the query, as if they were combined with a logical&nbsp;</span><code>AND</code><span>&nbsp;</span><span>operator.</span>
#
#
#         </td>
#       </tr>
#       <tr id="imgColorType">
#         <td><code>imgColorType</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Returns black and white, grayscale, or color images: <code>mono</code>, <code>gray</code>, and <code>color</code>.
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>color</code>": color
#             </li>
#             <li>"<code>gray</code>": gray
#             </li>
#             <li>"<code>mono</code>": mono
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="imgDominantColor">
#         <td><code>imgDominantColor</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Returns images of a specific dominant color.
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>black</code>": black
#             </li>
#             <li>"<code>blue</code>": blue
#             </li>
#             <li>"<code>brown</code>": brown
#             </li>
#             <li>"<code>gray</code>": gray
#             </li>
#             <li>"<code>green</code>": green
#             </li>
#             <li>"<code>pink</code>": pink
#             </li>
#             <li>"<code>purple</code>": purple
#             </li>
#             <li>"<code>teal</code>": teal
#             </li>
#             <li>"<code>white</code>": white
#             </li>
#             <li>"<code>yellow</code>": yellow
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="imgSize">
#         <td><code>imgSize</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Returns images of a specified size.
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>huge</code>": huge
#             </li>
#             <li>"<code>icon</code>": icon
#             </li>
#             <li>"<code>large</code>": large
#             </li>
#             <li>"<code>medium</code>": medium
#             </li>
#             <li>"<code>small</code>": small
#             </li>
#             <li>"<code>xlarge</code>": xlarge
#             </li>
#             <li>"<code>xxlarge</code>": xxlarge
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="imgType">
#         <td><code>imgType</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Returns images of a type.<code></code>
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>clipart</code>": clipart
#             </li>
#             <li>"<code>face</code>": face
#             </li>
#             <li>"<code>lineart</code>": lineart
#             </li>
#             <li>"<code>news</code>": news
#             </li>
#             <li>"<code>photo</code>": photo
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="linkSite">
#         <td><code>linkSite</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Specifies that all search results should contain a link to a particular URL
#
#
#         </td>
#       </tr>
#       <tr id="lowRange">
#         <td><code>lowRange</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>Specifies the starting value for a search range. <br></span><span>Use&nbsp;</span><code>lowRange&nbsp;</code><span>and</span><span>&nbsp;</span><code>highRange</code><span>&nbsp;</span><span>to append an inclusive search range of&nbsp;</span><code>lowRange...highRange</code><span>&nbsp;to the query.</span><span><br></span>
#
#
#         </td>
#       </tr>
#       <tr id="lr">
#         <td><code>lr</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           <span>Restricts the search to documents written in a particular language (e.g.,&nbsp;</span><code>lr=lang_ja</code><span>).</span>
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>lang_ar</code>": Arabic
#             </li>
#             <li>"<code>lang_bg</code>": Bulgarian
#             </li>
#             <li>"<code>lang_ca</code>": Catalan
#             </li>
#             <li>"<code>lang_cs</code>": Czech
#             </li>
#             <li>"<code>lang_da</code>": Danish
#             </li>
#             <li>"<code>lang_de</code>": German
#             </li>
#             <li>"<code>lang_el</code>": Greek
#             </li>
#             <li>"<code>lang_en</code>": English
#             </li>
#             <li>"<code>lang_es</code>": Spanish
#             </li>
#             <li>"<code>lang_et</code>": Estonian
#             </li>
#             <li>"<code>lang_fi</code>": Finnish
#             </li>
#             <li>"<code>lang_fr</code>": French
#             </li>
#             <li>"<code>lang_hr</code>": Croatian
#             </li>
#             <li>"<code>lang_hu</code>": Hungarian
#             </li>
#             <li>"<code>lang_id</code>": Indonesian
#             </li>
#             <li>"<code>lang_is</code>": Icelandic
#             </li>
#             <li>"<code>lang_it</code>": Italian
#             </li>
#             <li>"<code>lang_iw</code>": Hebrew
#             </li>
#             <li>"<code>lang_ja</code>": Japanese
#             </li>
#             <li>"<code>lang_ko</code>": Korean
#             </li>
#             <li>"<code>lang_lt</code>": Lithuanian
#             </li>
#             <li>"<code>lang_lv</code>": Latvian
#             </li>
#             <li>"<code>lang_nl</code>": Dutch
#             </li>
#             <li>"<code>lang_no</code>": Norwegian
#             </li>
#             <li>"<code>lang_pl</code>": Polish
#             </li>
#             <li>"<code>lang_pt</code>": Portuguese
#             </li>
#             <li>"<code>lang_ro</code>": Romanian
#             </li>
#             <li>"<code>lang_ru</code>": Russian
#             </li>
#             <li>"<code>lang_sk</code>": Slovak
#             </li>
#             <li>"<code>lang_sl</code>": Slovenian
#             </li>
#             <li>"<code>lang_sr</code>": Serbian
#             </li>
#             <li>"<code>lang_sv</code>": Swedish
#             </li>
#             <li>"<code>lang_tr</code>": Turkish
#             </li>
#             <li>"<code>lang_zh-CN</code>": Chinese (Simplified)
#             </li>
#             <li>"<code>lang_zh-TW</code>": Chinese (Traditional)
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="num">
#         <td><code>num</code></td>
#         <td><code class="apitype">unsigned integer</code></td>
#         <td>
#           Number of search results to return.<br><ul><li>Valid values are integers between 1 and 10, inclusive.</li></ul>
#
#
#         </td>
#       </tr>
#       <tr id="orTerms">
#         <td><code>orTerms</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Provides additional search terms to check for in a document, where each document in the search results must contain at least one of the additional search terms.
#
#
#         </td>
#       </tr>
#       <tr id="relatedSite">
#         <td><code>relatedSite</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Specifies that all search results should be pages that are related to the specified URL.
#
#
#         </td>
#       </tr>
#       <tr id="rights">
#         <td><code>rights</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Filters based on licensing. Supported values include: <code>cc_publicdomain</code>, <code>cc_attribute</code>, <code>cc_sharealike</code>, <code>cc_noncommercial</code>, <code>cc_nonderived,</code> and combinations of these.
#
#
#         </td>
#       </tr>
#       <tr id="safe">
#         <td><code>safe</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Search safety level.
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>high</code>": Enables highest level of SafeSearch filtering.
#             </li>
#             <li>"<code>medium</code>": Enables moderate SafeSearch filtering.
#             </li>
#             <li>"<code>off</code>": Disables SafeSearch filtering.
#               (default)
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="searchType">
#         <td><code>searchType</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Specifies the search type: <code>image</code>.&nbsp;<span>&nbsp;If unspecified, results are limited to webpages.</span>
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>image</code>": custom image search.
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="siteSearch">
#         <td><code>siteSearch</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Specifies all search results should be pages from a given site.
#
#
#         </td>
#       </tr>
#       <tr id="siteSearchFilter">
#         <td><code>siteSearchFilter</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           Controls whether to include or exclude results from the site named in the <code>siteSearch</code> parameter.
#
#           <br><br>Acceptable values are:
#           <ul>
#             <li>"<code>e</code>": exclude
#             </li>
#             <li>"<code>i</code>": include
#             </li>
#           </ul>
#
#         </td>
#       </tr>
#       <tr id="sort">
#         <td><code>sort</code></td>
#         <td><code class="apitype">string</code></td>
#         <td>
#           The sort expression to apply to the results.
#
#
#         </td>
#       </tr>
#       <tr id="start">
#         <td><code>start</code></td>
#         <td><code class="apitype">unsigned integer</code></td>
#         <td>
#           The index of the first result to return.
#
#
#         </td>
#       </tr>
#     </tbody>
#   </table>

# %% [markdown]
# ## Prepare The request

# %%
url = "https://www.googleapis.com/customsearch/v1"
parameters = {"q": 'cemento',
              "cx": cx,
              "key": key,
              "lr": "lang_es",
              "sort": "date:r:20161115:20161115",
              #"dateRestrict": 'd1',
              "excludeTerms": ''
              }

# %% [markdown]
# ## Make the request

# %%
page = requests.request("GET", url, params=parameters)

# %% [markdown]
# ## Process Results

# %%
results = json.loads(page.text)

# %% [markdown]
# ## Inspecting Results

# %%
results.keys()
# Out:
# [u'kind', u'url', u'items', u'context', u'queries', u'searchInformation']

# %% [markdown]
# ### Inspecting Search Meta Data

# %%
results["kind"]

# %%
results["url"]

# %%
len(results["items"])

# %%
results["queries"]
# Out:
# {u'nextPage': [{u'count': 10,
#    u'cx': u'009780631741676379950:7tjrahkzi3i',
#    u'excludeTerms': u'',
#    u'inputEncoding': u'utf8',
#    u'language': u'lang_es',
#    u'outputEncoding': u'utf8',
#    u'safe': u'off',
#    u'searchTerms': u'Saint Gobain',
#    u'sort': u'date:r:20161201:20170130',
#    u'startIndex': 11,
#    u'title': u'Google Custom Search - Saint Gobain',
#    u'totalResults': u'17400'}],
#  u'request': [{u'count': 10,
#    u'cx': u'009780631741676379950:7tjrahkzi3i',
#    u'excludeTerms': u'',
#    u'inputEncoding': u'utf8',
#    u'language': u'lang_es',
#    u'outputEncoding': u'utf8',
#    u'safe': u'off',
#    u'searchTerms': u'Saint Gobain',
#    u'sort': u'date:r:20161201:20170130',
#    u'startIndex': 1,
#    u'title': u'Google Custom Search - Saint Gobain',
#    u'totalResults': u'17400'}]}

# %%
results["searchInformation"]
# Out:
# {u'formattedSearchTime': u'0,66',
#  u'formattedTotalResults': u'6',
#  u'searchTime': 0.661376,
#  u'totalResults': u'6'}

# %%
page2 = requests.request("GET",url,params=results["queries"]["nextPage"][0])
results2 = json.loads(page2.text)
results2
# Out:
# {u'error': {u'code': 400,
#   u'errors': [{u'domain': u'global',
#     u'location': u'q',
#     u'locationType': u'parameter',
#     u'message': u'Required parameter: q',
#     u'reason': u'required'}],
#   u'message': u'Required parameter: q'}}

# %% [markdown]
# ## Inspecting a single result

# %%
results["items"][0]
# Out:
# {u'cacheId': u'EE8w6BDBQFEJ',
#  u'displayLink': u'www.alimarket.es',
#  u'formattedUrl': u'https://www.alimarket.es/.../saint-gobain-colabora-con-cruz-roja',
#  u'htmlFormattedUrl': u'https://www.alimarket.es/.../<b>saint</b>-<b>gobain</b>-colabora-con-cruz-roja',
#  u'htmlSnippet': u'hace 1 hora <b>...</b> En nombre de <b>Saint</b>-<b>Gobain</b> y como responsable de RSC para Espa\xf1a, <br>\nFernando Ledesma recibi\xf3 el agradecimiento de Cruz Roja Espa\xf1ola&nbsp;...',
#  u'htmlTitle': u'<b>Saint</b>-<b>Gobain</b> colabora con Cruz Roja - Noticias de Construcci\xf3n en ...',
#  u'kind': u'customsearch#result',
#  u'link': u'https://www.alimarket.es/noticia/233166/saint-gobain-colabora-con-cruz-roja',
#  u'pagemap': {u'cse_image': [{u'src': u'https://www.alimarket.es/media/images/2017/detalle_art/233166/168231_preview.jpg'}],
#   u'cse_thumbnail': [{u'height': u'187',
#     u'src': u'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRY0VNo5WTSsHNdZgbS5RzymrwUa4pazhCNINsLKOIBFD3vIhXjgA3190T0',
#     u'width': u'270'}],
#   u'imageobject': [{u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/233166/168231_preview.jpg',
#     u'height': u'200',
#     u'url': u'https://www.alimarket.es/media/images/2017/detalle_art/233166/168231_preview.jpg',
#     u'width': u'300'},
#    {u'height': u'58',
#     u'url': u'http://www.alimarket.es/style/img/lgo-alimarket.png',
#     u'width': u'280'},
#    {u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/233036/63433_preview.jpg',
#     u'height': u'200',
#     u'url': u'https://www.alimarket.es/media/images/2017/detalle_art/233036/63433_preview.jpg',
#     u'width': u'300'},
#    {u'height': u'58',
#     u'url': u'http://www.alimarket.es/style/img/lgo-alimarket.png',
#     u'width': u'280'},
#    {u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/232289/63280_preview.jpg',
#     u'height': u'200',
#     u'url': u'https://www.alimarket.es/media/images/2017/detalle_art/232289/63280_preview.jpg',
#     u'width': u'300'},
#    {u'height': u'58',
#     u'url': u'http://www.alimarket.es/style/img/lgo-alimarket.png',
#     u'width': u'280'},
#    {u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/232285/63279_preview.jpg',
#     u'height': u'200',
#     u'url': u'https://www.alimarket.es/media/images/2017/detalle_art/232285/63279_preview.jpg',
#     u'width': u'300'},
#    {u'height': u'58',
#     u'url': u'http://www.alimarket.es/style/img/lgo-alimarket.png',
#     u'width': u'280'},
#    {u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/231871/167674_preview.jpg',
#     u'height': u'200',
#     u'url': u'https://www.alimarket.es/media/images/2017/detalle_art/231871/167674_preview.jpg',
#     u'width': u'300'},
#    {u'height': u'58',
#     u'url': u'http://www.alimarket.es/style/img/lgo-alimarket.png',
#     u'width': u'280'},
#    {u'contenturl': u'https://www.alimarket.es/media/images/2017/detalle_art/231867/63121_preview.jpg',
#     u'height': u'200',
#     u'og:locale': u'es_ES',
#     u'og:site_name': u'Alimarket.es',
#     u'og:title': u'Saint-Gobain colabora con Cruz Roja - Noticias de Construcci\xf3n en Alimarket, informaci\xf3n econ\xf3mica sectorial',
#     u'og:type': u'news',
#     u'og:url': u'http://www.alimarket.es/noticia/233166/saint-gobain-colabora-con-cruz-roja',
#     u'twitter:card': u'summary',
#     u'twitter:creator': u'@Alimarket',
#     u'twitter:description': u'Saint-Gobain colabora con Cruz Roja',
#     u'twitter:domain': u'//www.alimarket.es',
#     u'twitter:image': u'https://www.alimarket.es/media/images/2017/detalle_art/233166/168231_preview.jpg',
#     u'twitter:site': u'@Alimarket',
#     u'twitter:title': u'Saint-Gobain colabora con Cruz Roja - Noticias de Construcci\xf3n en Alimarket, informaci\xf3n econ\xf3mica sectorial',
#     u'twitter:url': u'http://www.alimarket.es/noticia/233166/saint-gobain-colabora-con-cruz-roja',
#     u'viewport': u'width=device-width, initial-scale=1.0, maximum-scale=1.0'}],
#   u'newsarticle': [{u'articlebody': u'En nombre de Saint-Gobain y como responsable de RSC para Espa\xf1a, Fernando Ledesma recibi\xf3 el agradecimiento de Cruz Roja Espa\xf1ola de la mano de Carlos Pay\xe1 Riera, presidente de la instituci\xf3n...',
#     u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2012-03-24',
#     u'datepublished': u'2012-03-24',
#     u'headline': u'Saint-Gobain colabora con Cruz Roja'},
#    {u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2017-02-01',
#     u'datepublished': u'2017-02-01',
#     u'headline': u'Orkli instala suelo radiante en una promoci\xf3n de Aravaca',
#     u'name': u'Orkli instala suelo radiante en una promoci\xf3n de Aravaca',
#     u'url': u'Orkli instala suelo radiante en una promoci\xf3n de Aravaca'},
#    {u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2017-01-27',
#     u'datepublished': u'2017-01-27',
#     u'headline': u'Danfoss presenta nueva serie de intercambiadores de calor',
#     u'name': u'Danfoss presenta nueva serie de intercambiadores de calor',
#     u'url': u'Danfoss presenta nueva serie de intercambiadores de calor'},
#    {u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2017-01-26',
#     u'datepublished': u'2017-01-26',
#     u'headline': u'Grundfos integra en una \xfanica compa\xf1\xeda su actividad en la Pen\xednsula Ib\xe9rica',
#     u'name': u'Grundfos integra en una \xfanica compa\xf1\xeda su actividad en la Pen\xednsula Ib\xe9rica',
#     u'url': u'Grundfos integra en una \xfanica compa\xf1\xeda su actividad en la Pen\xednsula Ib\xe9rica'},
#    {u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2017-01-25',
#     u'datepublished': u'2017-01-25',
#     u'headline': u'Stauff presenta uniones roscadas inclinables para presi\xf3n media',
#     u'name': u'Stauff presenta uniones roscadas inclinables para presi\xf3n media',
#     u'url': u'Stauff presenta uniones roscadas inclinables para presi\xf3n media'},
#    {u'articlesection': u'Fontaner\xeda',
#     u'datecreated': u'2017-01-20',
#     u'datepublished': u'2017-01-20',
#     u'headline': u'Manel Antequera asume la direcci\xf3n general de La Farga Tub',
#   u'person': [{u'name': u'Alimarket Construcci\xf3n'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'},
#    {u'name': u'Publicaciones Alimarket'}]},
#  u'snippet': u'hace 1 hora ... En nombre de Saint-Gobain y como responsable de RSC para Espa\xf1a, \nFernando Ledesma recibi\xf3 el agradecimiento de Cruz Roja Espa\xf1ola\xa0...',
#  u'title': u'Saint-Gobain colabora con Cruz Roja - Noticias de Construcci\xf3n en ...'}

# %% [markdown]
# # Process Results Into a Pandas Data Frame

# %%
def process_search(results):
    link_list = [item["link"] for item in results["items"]]
    df = pd.DataFrame(link_list, columns=["link"])
    df["title"] = [item["title"] for item in results["items"]]
    df["snippet"] = [item["snippet"] for item in results["items"]]
    return df
df = process_search(results)
df
# Out:
#                                                 link  \
# 0  http://www.lavozdegalicia.es/noticia/coruna/co...
# 1  http://www.americatv.com.pe/noticias/redes-soc...
# 2  http://publimetro.pe/deportes/noticia-esta-car...
# 3  http://www.americatv.com.pe/deportes/eliminato...
# 4  http://elcomercio.pe/deporte-total/seleccion/s...
# 5  http://depor.com/futbol-peruano/seleccion-peru...
#
#                                                title  \
# 0  Comenzó el arreglo de dos cámaras para sacar h...
# 1  YouTube: agujero gigante que apareció en Japón...
# 2  Esta es la carta de un niño con leucemia a la ...
# 3  André Carrillo compartió emotiva carta de niño...
# 4  Selección peruana: André Carrillo compartió en...
# 5  André Carrillo compartió emotiva carta que env...
#
#                                              snippet
# 0  15 Nov 2016 ... Comenzó el arreglo de dos cáma...
# 1  15 Nov 2016 ... Los trabajos de relleno con ar...
# 2  15 Nov 2016 ... “Amo el futbol, jugué mucho ti...
# 3  15 Nov 2016 ... Amo el futbol, jugué mucho tie...
# 4  15 Nov 2016 ... Amo el fútbol, jugué mucho tie...
# 5  15 Nov 2016 ... Amo el fútbol, jugué mucho tie...

# %%
links = [item["link"] for item in results["items"]]

edges = ["articleBody","author","creator","dateCreated","datePublished","dateModified","keywords",'title']
meta_edge_dict = {
    "dateModified": ["article:modified_time", "date"],
    "datePublished": ["article:published_time", "dc.date.issued"],
    "keywords": ["article:tag"],
    "title": ["og:title", "twitter:title"]
}

contents = []
for item in results["items"]:
    response = request(item['link'])
    html = response.content
    soup = BeautifulSoup(html,"html.parser")

    [s.extract() for s in soup('script')]
    [s.extract() for s in soup('style')]
    #[s.extract() for s in soup('meta')]
    
    contents += [{}]
                
    for edge in edges:
        if edge not in contents[-1]:
            found = soup.select('[itemprop="' + edge + '"]')
            if len(found) > 0:
                contents[-1][edge] = found[0].get_text()
            else:
                contents[-1][edge] = None
    
    for edge in [edge for edge, val in contents[-1].items() if not val]:
        if edge.lower() in item['pagemap']['newsarticle'][0]:
            contents[-1][edge] = item['pagemap']['newsarticle'][0][edge.lower()]
        elif edge.lower() in item['pagemap']['metatags'][0]:
            contents[-1][edge] = item['pagemap']['metatags'][0][edge.lower()]
    
    for edge in [edge for edge, val in contents[-1].items() if not val and edge in meta_edge_dict]:
        for tag in meta_edge_dict[edge]:
            if tag in item['pagemap']['metatags'][0]:
                contents[-1][edge] = item['pagemap']['metatags'][0][tag]
                break
                

contents
# Out:
# [{'articleBody': u'\n\n\nLa producci\xf3n nacional correspondiente a setiembre registr\xf3 un crecimiento de 4.13% en comparaci\xf3n con el mismo mes del 2015, inform\xf3 el Instituto Nacional de Estad\xedstica e Inform\xe1tica (INEI). \nDicho resultado fue mayor al 3.8% proyectado por un sondeo de Reuters y al 4% esperado por el Banco Central de Reserva (BCRP).\nCon ello, la actividad econ\xf3mica peruana entre enero y setiembre present\xf3 una variaci\xf3n acumulada de 4.20% y una tasa interanual (octubre de 2015-setiembre de 2016) de 4.34%. La entidad indica que este resultado favorable se debe al comportamiento positivo de la demanda externa y las mayores exportaciones.\nPor sectores\nEl rubro de la pesca fue el que m\xe1s se expandi\xf3 ante la mayor captura de especies mar\xedtimas para consumo humano directo (23.08%), sobre todo para curado (39.3%), congelado (33.8%) y enlatado (146.4%). \nSin embargo, la pesca para consumo humano indirecto registr\xf3 una contracci\xf3n de 100% en setiembre debido a la nula extracci\xf3n de anchoveta por la veda que se present\xf3 en la primera temporada de pesca de este recurso.\nEl sector de miner\xeda e hidrocarburos fue el otro motor de crecimiento de la econom\xeda,  ya que creci\xf3 14.23%. Dentro del mismo, el subsector de miner\xeda (16.62%) fue el que m\xe1s creci\xf3 por la extracci\xf3n de cobre (35.9%), molibdeno (25.1%) y oro (3.1%). \nAsimismo, el subsector de hidrocarburos creci\xf3 2.08%, por el aumento de la explotaci\xf3n de l\xedquidos de gas natural (16.74%) y de gas natural (30.36%).\nFinalmente, el sector construcci\xf3n present\xf3 una ca\xedda de 3.81% debido al menor consumo interno de cemento y la menor inversi\xf3n en obras del gobierno nacional y regionales. \nDatos\n\nEl ministro de Econom\xeda, Alfredo Thorne, indic\xf3 que estas cifras de crecimiento son optimistas.\n\n\nEl sector manufactura creci\xf3 2.65% debido a la mayor producci\xf3n del subsector fabril primario.\n \n\n\n              Si te interes\xf3 lo que acabas de leer, recuerda que puedes seguir nuestras \xfaltimas publicaciones por Facebook, Twitter\n              y puedes suscribirte aqu\xed a nuestro newsletter.\n            \n\n\nPeru21.pe\n\n',
#   'author': None,
#   'creator': None,
#   'dateCreated': None,
#   'dateModified': u'Martes 15 de noviembre del 2016 | 20:50 ',
#   'datePublished': u'\n La cifra reportada es ligeramente mayor a la proyectada por el Banco Central de Reserva.\n\n\nProducci\xf3n nacional registr\xf3 crecimiento de 4.13% en setiembre, inform\xf3 INEI. (USI)\n\n',
#   'keywords': u'PBI',
#   'title': u'INEI: Producci\xf3n nacional registr\xf3 crecimiento de 4.13% en setiembre'},
\xf3n p\xfablico-privada -se\xf1al\xf3- permiti\xf3 desatascar planeamientos que estaban paralizados y que los nuevos desarrollos se pudieran ejecutar en plazos razonables de entre cinco y diez a\xf1os'. Para Murcia Puchades, 'es bueno adoptar medidas de control pero es un error que se elimine la colaboraci\xf3n p\xfablico-privada porque eso supondr\xe1, que ante una inversi\xf3n, en lugar de hablar de siete u ocho a\xf1os, hablemos de mucho m\xe1s tiempo, y eso espanta al inversor'.Posible bloqueoEn cuanto a la posibilidad de reducir y dividir los planes parciales a cambio de otorgar 10 a\xf1os m\xe1s de plazo para el inicio de las obras, desde Feprova mantienen que se trata de un aspecto que 'ya estaba vigente en la legislaci\xf3n actual, aunque una mayor claridad es valorada positivamente'. No obstante, Murcia Puchades advierte de que 'fijar un plazo de ejecuci\xf3n para el desarrollo de estos programas puede distorsionar el mercado, pues habr\xe1 programas que necesitar\xe1n desarrollarse en cinco a\xf1os y otros en 15. Adem\xe1s, las medidas coercitivas por incumplir el plazo pueden dar lugar a responsabilidad patrimonial de la Administraci\xf3n'.Sobre el Plan de Acci\xf3n Territorial de la Infraestructura Verde de Litoral (Pativel), que incluye la protecci\xf3n de casi 6.500 hect\xe1reas de la costa, los promotores defienden que 'no se ha alcanzado una proporcionalidad entre la pro ...
#   'author': u'rhapt',
#   'creator': None,
#   'dateCreated': u'\n16/11/2016\n13:52 horas\n',
#   'dateModified': u'\n16/11/2016 09:02',
#   'datePublished': u"\n16/11/2016 09:02No llegan buenas noticias desde la Generalitat para los promotores inmobiliarios. El giro dado por PSPV y Comprom\xeds a la pol\xedtica urban\xedstica, traducido en una amplia protecci\xf3n del litoral y en unas limitaciones m\xe1s severas al papel de las empresas en los planes parciales, est\xe1 desinflando las expectativas de un sector que empieza a levantar cabeza despu\xe9s de pasar lo peor de su particular crisis. La Conselleria de Vivienda, Obras P\xfablicas y Vertebraci\xf3n del Territorio, que encabeza Mar\xeda Jos\xe9 Salvador, est\xe1 sentando las bases de un nuevo urbanismo valenciano. El viraje, que entre otras cosas, prev\xe9 impedir que las promotoras impulsen las reclasificaciones de suelo, se plasmar\xe1 en una profunda reforma de la Ley de Ordenaci\xf3n del Territorio, Urbanismo y Paisaje (Lotup), supone un torpedo a la l\xednea de flotaci\xf3n del ladrillo. Y es que los empresarios del sector, a trav\xe9s de la Federaci\xf3n de Promotores Inmobiliarios y Agentes Urbanizadores de la Comunidad Valenciana (Feprova), consideran que los planes del Consell perjudican seriamente la recuperaci\xf3n de la actividad. El presidente de la patronal, Francisco Murcia Puchades, no dud\xf3 ayer en cargar contra la hoja de ruta de la conselleria, al asegurar que una de las propuestas estrella de Salvador, consistente en eliminar la posibilidad de que los particulares puedan proponer reclasificaciones de suelo, 'es una medida innecesaria porque la decisi\xf3n \xfaltima siempre ha sido de los ayuntamientos y de la Generalitat'. En declaraciones a este peri\xf3dico, Murcia Puchades se mostr\xf3 cr\xedtico con la supresi\xf3n de la colaboraci\xf3n p\xfablico-privada en la gesti\xf3n de los planes parciales -PAI- (la reforma se decanta por una gesti\xf3n directa de las actuaciones). A este respecto, el presidente de los promotores afirm\xf3 que 'una de las ventajas que supuso la aprobaci\xf3n de la Ley Urban\xedstica en 1995 fue impulsar la colaboraci\xf3n p\xfablico-privada. Ello permiti\xf3 agilizar la burocracia y atrajo inversi\xf3n a nuestra regi\xf3n. La colaboraci\xf3n p\xfablico-privada -se\xf1al\xf3- permiti\xf3 desatascar planeamientos que estaban paralizados y que los nuevos desarrollos se pudieran ejecutar en plazos razonables de entre cinco y diez a\xf1os'. Para Murcia Puchades, 'es bueno adoptar medidas de control pero es un error que se elimine la colaboraci\xf3n p\xfablico-privada porque eso supondr\xe1, que ante una inversi\xf3n, en lugar de hablar de siete u ocho a\xf1os, hablemos de mucho m\xe1s tiempo, y eso espanta al inversor'.Posible bloqueoEn cuanto a la posibilidad de reducir y dividir los planes parciales a cambio de otorgar 10 a\xf1os m\xe1s de plazo para el inicio de las obras, desde Feprova mantienen que se trata de un aspecto que 'ya estaba vigente en la legislaci\xf3n actual, aunque una mayor claridad es valorada positivamente'. No obstante, Murcia Puchades advierte de que 'fijar un plazo de ejecuci\xf3n para el desarrollo de estos programas puede distorsionar el mercado, pues habr\xe1 programas que necesitar\xe1n desarrollarse en cinco a\xf1os y otros en 15. Adem\xe1s, las medidas coercitivas por incumplir el plazo pueden dar lugar a responsabilidad patrimonial de la Administraci\xf3n'.Sobre el Plan de Acci\xf3n Territorial de la Infraestructura Verde de Litoral (Pativel), que incluye la protecci\xf3n de casi 6.500 hect\xe1reas de la costa, los promotores defienden que 'no se ha alcanzado una proporcionalidad entre la protecci\xf3n del litoral y la actividad econ\xf3mica'. Un ejemplo es el desarrollo de campos de golf sin viviendas, algo que en opini\xf3n de los empresarios, resulta inviable con las nuevas prescripciones del Consell y que afecta de lleno al turismo residencial. Asimismo, la patronal ve con preocupaci\xf3n 'que no se haya previsto una importante partida de indemnizaciones en el Pativel, porque no cabe duda de que se incurrir\xe1 en responsabilid ...
#   'keywords': u'comunidad-valenciana/alicante',
#   'title': u'Inicio'}]

# %%
def request(link):

    if "obscure" in globals():
        sleep(random.uniform(0.05,1.5))
        head = {'user-agent': user_agents[int(random.uniform(0,156.9999))]};
        for trials in range(1,5):
            r = requests.get(link, headers=head)
            if r.status_code == requests.codes.ok:
                break
    
    else:
        for trials in range(1,5):
            r = requests.get(link)
            if r.status_code == requests.codes.ok:
                break
    
    return r

response = request(df.loc[3]["link"])
html = response.content
soup = BeautifulSoup(html,"html.parser")

[s.extract() for s in soup('script')]
[s.extract() for s in soup('style')]
#[s.extract() for s in soup('meta')]

#print "\n".join([it.get_text() for it in soup.select('[itemprop="articleBody"] > *')])

print(soup.select('[itemprop="articleBody"]')[0].get_text())
# Out:
# LUNES, 9 de marzo (HealthDay News/Dr. Tango) -- Inyectar "cemento óseo" en las lesiones de pacientes cuyo cáncer se ha propagado a los huesos puede permitirle literalmente a estos individuos levantarse de su lecho de muerte y vivir el resto de su vida relativamente libres de dolor. Los investigadores italianos que presentaron estos hallazgos en la reunión anual de la Society of Interventional Radiology en San Diego lo llamaron "Efecto Lázaro", haciendo alusión al milagro de la resurrección de Lázaro mencionado en la Biblia. "La mayoría de los pacientes tratados experimentaron alivio significativo, completo o duradero del dolor luego de la osteopatía con una mejora inmediata de las afecciones clínicas y la calidad de vida", señaló el Dr. Giovanni Carlo Anselmetti, autor del estudio, del Instituto de investigación y tratamiento del cáncer de Turín. De hecho, una monja de 79 años que estaba limitada a guardar cama por un cáncer de tiroides que se había propagado a su pelvis se levantó y anduvo apenas dos horas después del procedimiento mínimamente invasivo. "Es paliativo. No va a ser un procedimiento curativo, pero hemos visto mejoras dramáticas en el control del dolor", señaló el Dr. Mark Montgomery, profesor asociado de radiología del colegio de medicina del Centro de ciencias de la salud Texas A&M  y director de radiología de intervención y vicepresidente de educación y radiología del Scott & White. El procedimiento se usa más comúnmente en la columna, señaló la Dra. Susan Bukata, oncóloga ortopedista del Centro médico de la Universidad de Rochester. Los ortopedistas que hacen osteoplastia generalmente se asocian con un radiólogo de intervención, que primero hace una ablación por radiofrecuencia (calor extremo) o crioablación (congelamiento) para acabar con las neuronas cercanas al tumor. La osteoplastia consiste en inyectar cemento óseo (en este caso se usa polimetil metacrilato o PMMA) en una lesión ósea con la ayuda de guía por imágenes. "El procedimiento es análogo a la vertebroplastia, que se ha usado durante algunos años, en la que se introducen agujas pequeñas en la columna y se inyecta una mezcla de cemento", explicó Montgomery. "Es el mismo tipo de cemento que se usa para el reemplazo de cadera. Esto es lo mismo, excepto que simplemente están sacando el uso de la columna a otras áreas". En el estudio participaron 81 pacientes entre 36 y 94 años, principalmente mujeres, que se sometieron a la osteoplastia al menos una vez. De los pacientes, 74 tenían cáncer, mientras que un puñado de ellos tenía enfermedades "benignas" como artritis reumatoide.  La población general de pacientes fue mayor que la observada en otros estudios, aseguró Bukata. Se trataron huesos pélvicos, fémur, sacro, costillas, rodillas y otros. El puntaje de dolor medio se redujo significativamente en cuestión de 24 horas después del procedimiento. De los pacientes, 64 (el 79 por ciento) lograron eliminar el uso de narcóticos, mientras que 43 (el 53 por ciento) también dejaron de usar otros analgésicos. Apenas cinco de los pacientes no mostraron mejoras en el dolor. No hubo muertes ni complicaciones de consideración. El procedimiento también podría ser usado para evitar cirugía masiva años después, aseguró Bukata. "Hay falta de concienciación sobre algunas de las opciones para los pacientes que tienen metástasis óseas dolorosas", agregó Montgomery. "Es tanto educación de médicos como de pacientes". Más información La Sociedad Estadounidense del Cáncer tiene más información sobre la metástasis en los huesos. Artículo por HealthDay, traducido por Dr. Tango

# %% [markdown]
# # Getting Results from more pages

# %% [markdown]
# Use `"start"` parameter to skip results from previous pages. To get the next `"start"` index look it up in `"queries.nextPage[0].startIndex"`

# %%
next_index = results["queries"]["nextPage"][0]["startIndex"]
search_terms = results["queries"]["nextPage"][0]["searchTerms"]

url = "https://www.googleapis.com/customsearch/v1"
parameters = {"q": search_terms,
              "cx": cx,
              "key": key,
              "start": next_index
              }

# %%
page = requests.request("GET", url, params=parameters)
results = json.loads(page.text)

# %%
def process_search(results):
    link_list = [item["link"] for item in results["items"]]
    df = pd.DataFrame(link_list, columns=["link"])
    df["title"] = [item["title"] for item in results["items"]]
    df["snippet"] = [item["snippet"] for item in results["items"]]
    return df
temp_df = process_search(results)
df = pd.concat([df, temp_df], ignore_index=True)
df
